# %% [markdown]
# # TFM Banco Checo

# %%
import pandas as pd
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Cargamos los datos que hemos procesado en R
df= pd.read_csv("DFBancoCheco.csv")

# %%
df
# Out:
#       Unnamed: 0  account_id  district_id frequency Date_Account  \
# 0              1         576           18   Monthly   1995-03-24
# 1              2        3818            1   Monthly   1993-02-26
# 2              3         704            5   Monthly   1997-07-07
# 3              4        2378           12   Monthly   1996-02-21
# 4              5        2632           15   Monthly   1997-05-30
# 5              6        1972           51   Monthly   1994-09-27
# 6              7        1539           60   Monthly   1996-11-24
# 7              8         793           57   Monthly   1995-09-21
# 8              9        2484           70   Monthly   1993-01-27
# 9             10        1695           54   Monthly   1996-08-28
# 10            11        1726           76   Monthly   1995-10-10
# 11            12        2881           21   Monthly   1997-04-15
# 12            13        2357           76   Monthly   1997-08-17
# ...

# %% [markdown]
# # Vamos a ver si somos capaces de predecir si un cliente tiene préstamo o no lo tiene

# %%
#Vemos si las variables se han importado como esperabamos y vemos que los factores no se han importado como esperábamos
df.dtypes
# Out:
# Unnamed: 0                           int64
# account_id                           int64
# district_id                          int64
# frequency                           object
# Date_Account                        object
# client_id_owner                      int64
# client_id_disponent                  int64
# loan_id                              int64
# Date_Loan                           object
# Amount_Loan                        float64
# Duration_Loan                        int64
# Payments_Loan                        int64
# Status_Loan                         object
# Ord_Insurance                        int64
# Ord_Insurance_imp                    int64
# Ord_Household                        int64
# Ord_Household_imp                    int64
# Ord_Loan                             int64
# Ord_Loan_imp                         int64
# Ord_Leasing                          int64
# Ord_Leasing_imp                      int64
# owner_card                           int64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0    account_id  district_id  client_id_owner  \
# count  4500.000000   4500.000000  4500.000000      4500.000000
# mean   2250.500000   2786.067556    37.310444      3381.096444
# std    1299.182435   2313.811984    25.177217      2839.605215
# min       1.000000      1.000000     1.000000         1.000000
# 25%    1125.750000   1182.750000    13.000000      1424.750000
# 50%    2250.500000   2368.000000    38.000000      2861.000000
# 75%    3375.250000   3552.250000    60.000000      4287.250000
# max    4500.000000  11382.000000    77.000000     13998.000000
#
#        client_id_disponent      loan_id    Amount_Loan  Duration_Loan  \
# count          4500.000000  4500.000000     682.000000    4500.000000
# mean              0.193111     0.151556  151410.175953       5.530667
# std               0.394783     0.358629  113372.406310      14.676907
# min               0.000000     0.000000    4980.000000       0.000000
# ...

# %%
df.describe(include = "all")
# Out:
#          Unnamed: 0    account_id  district_id frequency Date_Account  \
# count   4500.000000   4500.000000  4500.000000      4500         4500
# unique          NaN           NaN          NaN         3         1535
# top             NaN           NaN          NaN   Monthly   1993-02-08
# freq            NaN           NaN          NaN      4167           13
# mean    2250.500000   2786.067556    37.310444       NaN          NaN
# std     1299.182435   2313.811984    25.177217       NaN          NaN
# min        1.000000      1.000000     1.000000       NaN          NaN
# 25%     1125.750000   1182.750000    13.000000       NaN          NaN
# 50%     2250.500000   2368.000000    38.000000       NaN          NaN
# 75%     3375.250000   3552.250000    60.000000       NaN          NaN
# max     4500.000000  11382.000000    77.000000       NaN          NaN
#
#         client_id_owner  client_id_disponent      loan_id   Date_Loan  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# account_id                            int64
# district_id                           int64
# frequency                            object
# Date_Account                         object
# client_id_owner                       int64
# client_id_disponent                   int64
# loan_id                               int64
# Date_Loan                            object
# Amount_Loan                         float64
# Duration_Loan                         int64
# Payments_Loan                         int64
# Status_Loan                          object
# Ord_Insurance                         int64
# Ord_Insurance_imp                     int64
# Ord_Household                         int64
# Ord_Household_imp                     int64
# Ord_Loan                              int64
# Ord_Loan_imp                          int64
# Ord_Leasing                           int64
# Ord_Leasing_imp                       int64
# ...

# %%
df["Ord_Insurance_Bin"] = df["Ord_Insurance_Bin"].astype('category')
